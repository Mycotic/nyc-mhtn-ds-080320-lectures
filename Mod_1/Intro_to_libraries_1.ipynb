# %% [markdown]
# # Python Libraries 1
#
# _Aug 5, 2020_
#
# Agenda today:
# - Introduction to Numpy: array math
# - Introduction to Pandas: importing, indexing, and math

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part I. Numpy
# The basic data structure that exist in numpy is called numpy arrays. NP arrays are very similar to python lists. The __difference__ between a python list and a Numpy array is that list can only a mix of data types but array can only contain the same data type.
#
# But what is the benefits of using NumPy array instead of the base python lists?
# - Speed
# - Broadcasting Property

# %%
names_list=['Bob','John','Sally']
names_array=np.char.array(['Bob','John','Sally']) #use numpy.array for numbers and numpy.char.array for strings
print(names_list)
print(names_array)
# Out:
# ['Bob', 'John', 'Sally']
# ['Bob' 'John' 'Sally']

# %%
import time

size_of_seq = 100000

def pure_python_version():
    tic = time.time()
    X = range(size_of_seq)
    Y = range(size_of_seq)
    Z = [X[i] + Y[i] for i in range(len(X)) ]
    toc = time.time()
    return toc - tic

def numpy_version():
    tic = time.time()
    X = np.arange(size_of_seq)
    Y = np.arange(size_of_seq)
    Z = X + Y 
    toc = time.time()
    return toc - tic


t1 = pure_python_version()
t2 = numpy_version()
print("python: " + str(t1), "numpy: "+ str(t2))
print("Numpy is in this example " + str(t1/t2) + " times faster!")
# Out:
# python: 0.04746603965759277 numpy: 0.0007760524749755859
# Numpy is in this example 61.163440860215054 times faster!

# %%
## broadcasting and array math

np.array([2,3,4,6]) * 5
# Out:
# array([10, 15, 20, 30])

# %%
li = [2,3,4,6]
li * 5
# Out:
# [2, 3, 4, 6, 2, 3, 4, 6, 2, 3, 4, 6, 2, 3, 4, 6, 2, 3, 4, 6]

# %%
## simulation with numpy - in normal distribution

# %% [markdown]
# There are many other wonderous things numpy can do, you will encounter them later in the course of the program.

# %% [markdown]
# ## Part II. Pandas
# Pandas stand for paneled data, and it is the most popular library for data scientists to manipulate, clean, and organize dataset in Python. The most fundamental data structure that exists in Pandas is called **DataFrames**.

# %%
## importing data and look at optional parameters
df = pd.read_csv('auto-mpg.csv')
df.head()
print(type(df.dtypes))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# examine and read the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df["horsepower"] = df["horsepower"].map(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-151804aeaf23> in <module>
# ----> 1 df["horsepower"] = df["horsepower"].map(int)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3628         dtype: object
#    3629         """
# -> 3630         new_values = super()._map_values(arg, na_action=na_action)
#    3631         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3632
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1152
#    1153         # mapper is a function
# -> 1154         new_values = map_f(values, mapper)
#    1155
#    1156         return new_values
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# ValueError: invalid literal for int() with base 10: '?'

# %%
def tellme(string):
    try:
        return int(string)
    except:
        print(string)

# %%
df["norsepower"] = df["horsepower"].replace("?",None).map(float)

# %%
df["norsepower"].map(print)
# Out:
# 130.0
# 165.0
# 150.0
# 150.0
# 140.0
# 198.0
# 220.0
# 215.0
# 225.0
# 190.0
# 170.0
# 160.0
# 150.0
# 225.0
# 95.0
# 95.0
# 97.0
# 85.0
# 88.0
# 46.0
# 75.0
# 95.0
# 105.0
# 85.0
# 97.0
# 103.0
# 125.0
# 115.0
# 133.0
# 71.0
# 68.0
# 115.0
# 85.0
# 88.0
# 90.0
# 110.0
# 130.0
# 129.0
# 138.0
# 135.0
# 155.0
# 142.0
# 125.0
# 150.0
# 71.0
# 65.0
# 80.0
# 80.0
# 77.0
# 125.0
# 71.0
# 90.0
# 70.0
# 70.0
# 65.0
# 69.0
# 90.0
# 115.0
# 115.0
# 90.0
# 76.0
# 60.0
# 70.0
# 65.0
# 90.0
# 88.0
# 90.0
# 90.0
# 78.0
# 90.0
# 75.0
# 92.0
# 75.0
# 65.0
# 105.0
# 65.0
# 48.0
# 48.0
# 67.0
# 67.0
# 67.0
# 67.0
# 67.0
# 62.0
# 132.0
# 100.0
# 88.0
# 88.0
# 72.0
# 84.0
# 84.0
# 92.0
# 110.0
# 84.0
# 58.0
# 64.0
# 60.0
# 67.0
# 65.0
# 62.0
# 68.0
# 63.0
# 65.0
# 65.0
# 74.0
# 74.0
# 75.0
# 75.0
# 100.0
# 74.0
# 80.0
# 76.0
# 116.0
# 120.0
# 110.0
# 105.0
# 88.0
# 85.0
# 88.0
# 88.0
# 88.0
# 85.0
# 84.0
# 90.0
# 92.0
# 92.0
# 74.0
# 68.0
# 68.0
# 63.0
# 70.0
# 88.0
# 75.0
# 70.0
# 67.0
# 67.0
# 67.0
# 110.0
# 85.0
# 92.0
# 112.0
# 96.0
# 84.0
# 90.0
# 86.0
# 52.0
# 84.0
# 79.0
# 82.0
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 393    None
# 394    None
# 395    None
# 396    None
# 397    None
# Name: norsepower, Length: 398, dtype: object

# %%
# indexing and subsetting 
df.loc[df["horsepower"]=="?"]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 32   25.0          4          98.0          ?    2046          19.0
# 126  21.0          6         200.0          ?    2875          17.0
# 330  40.9          4          85.0          ?    1835          17.3
# 336  23.6          4         140.0          ?    2905          14.3
# 354  34.5          4         100.0          ?    2320          15.8
# 374  23.0          4         151.0          ?    3035          20.5
#
#      model year  origin              car name  norsepower
# 32           71       1            ford pinto        95.0
# 126          74       1         ford maverick        95.0
# 330          80       2  renault lecar deluxe        67.0
# 336          80       1    ford mustang cobra        88.0
# 354          81       2           renault 18i        74.0
# 374          82       1        amc concord dl        92.0

# %%
# examine whether we have missing value - it could really affect the data!
df.loc[335]
# Out:
# mpg                            35
# cylinders                       4
# displacement                  122
# horsepower                     88
# weight                       2500
# acceleration                 15.1
# model year                     80
# origin                          2
# car name        triumph tr7 coupe
# norsepower                     88
# Name: 335, dtype: object

# %%
# exercise - get the cars that are heavier than 3000 but has a horsepower less than 150 

# should be 150 cars that satisfy the criteria 
a=[1,2,3]
print(list(map(float,a)))
# Out:
# [1.0, 2.0, 3.0]

# %%
# why do we seem to have anomaly in our data?

# %%
# get rid of anomaly

# %%
# exercise - get a list of car name where the mpg is less than 18 and weight is greater than 3500

# there should be 91 cars
